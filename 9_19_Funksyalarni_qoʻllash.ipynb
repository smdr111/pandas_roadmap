# %% [markdown]
# ![Imgur](https://i.imgur.com/h4PPC71.png)
# #Data Sayns va Sunʼiy Intellekt Praktikum
# Maʼlumotlar tahlili. Pandas kutubxonasi.
#
# 9.19. Funksiyalarni qoʻllash.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.090508 -0.534295  1.331517  0.253681
# b  0.085130 -2.321960  0.105061  0.964642
# c  1.599441 -0.347150  1.662671  1.499375

# %%
np.abs(-5)
# Out:
# np.int64(5)

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anjir
# a   0.0  -1.0    1.0    0.0
# b   0.0  -2.0    0.0    1.0
# c   2.0  -0.0    2.0    1.0

# %%
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.090508 -0.534295  1.331517  0.253681
# b  0.085130 -2.321960  0.105061  0.964642
# c  1.599441 -0.347150  1.662671  1.499375

# %%
df.mean()
# Out:
# Olma     0.591693
# Anor    -1.067802
# Qovun    1.033083
# Anjir    0.905899
# dtype: float64

# %%
df.apply(np.abs)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.090508  0.534295  1.331517  0.253681
# b  0.085130  2.321960  0.105061  0.964642
# c  1.599441  0.347150  1.662671  1.499375

# %%
df.apply(sum, axis=1)
# Out:
# a    1.141411
# b   -1.167127
# c    4.414337
# dtype: float64

# %%
f = lambda x: x.max()-x.min()

# %%
df.apply(f)
# Out:
# Olma     1.514311
# Anor     1.974809
# Qovun    1.557610
# Anjir    1.245694
# dtype: float64

# %%
def foo(x):
  return pd.Series([x.min(),x.max()], index=['min','max'])

# %%
df.apply(foo)
# Out:
#          Olma     Anor     Qovun     Anjir
# min  0.085130 -2.32196  0.105061  0.253681
# max  1.599441 -0.34715  1.662671  1.499375

# %%
df = pd.DataFrame(np.arange(1,13).reshape(3,4),index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])

# %%
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     2      3      4
# b     5     6      7      8
# c     9    10     11     12

# %%
df.applymap(lambda x: x*x)
# Out:
# <ipython-input-19-3f70e169ad84>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x*x)
#    Olma  Anor  Qovun  Anjir
# a     1     4      9     16
# b    25    36     49     64
# c    81   100    121    144
